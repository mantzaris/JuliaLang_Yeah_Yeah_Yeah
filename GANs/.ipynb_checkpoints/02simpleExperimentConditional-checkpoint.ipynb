# %%
using Images, TestImages, ImageIO, ImageMagick, ImageView, Colors
using StatsBase, Statistics, LinearAlgebra, Plots, Random
using Flux

# %%
NN = 10 #side length of images generated

function noisySquare() #make a 'noisy' square image
    newPic = ones(NN,NN)
    for rr = 1:NN
        for cc = 1:NN
            if( (rr >= 3 && rr <= 7) && (cc >= 3 && cc <= 7) )
                if( rand() >= 0.1 ) newPic[rr,cc] = 0 end
            end
        end
    end
    return newPic
end

function noisyCross() #function 'noisy cross' image generator
    newPic = ones(NN,NN)
    for rr = 1:NN
        for cc = 1:NN
            if( rr == 5 || cc == 5 )
                if( rand() >= 0.1 ) newPic[rr,cc] = 0 end
            end
        end
    end
    return newPic
end
# Out:
# noisyCross (generic function with 1 method)

# %%
Gray.( noisySquare() ) #make a sample noisy square
# Out:
# 10×10 Array{Gray{Float64},2} with eltype Gray{Float64}:
#  Gray{Float64}(1.0)  Gray{Float64}(1.0)  …  Gray{Float64}(1.0)
#  Gray{Float64}(1.0)  Gray{Float64}(1.0)     Gray{Float64}(1.0)
#  Gray{Float64}(1.0)  Gray{Float64}(1.0)     Gray{Float64}(1.0)
#  Gray{Float64}(1.0)  Gray{Float64}(1.0)     Gray{Float64}(1.0)
#  Gray{Float64}(1.0)  Gray{Float64}(1.0)     Gray{Float64}(1.0)
#  Gray{Float64}(1.0)  Gray{Float64}(1.0)  …  Gray{Float64}(1.0)
#  Gray{Float64}(1.0)  Gray{Float64}(1.0)     Gray{Float64}(1.0)
#  Gray{Float64}(1.0)  Gray{Float64}(1.0)     Gray{Float64}(1.0)
#  Gray{Float64}(1.0)  Gray{Float64}(1.0)     Gray{Float64}(1.0)
#  Gray{Float64}(1.0)  Gray{Float64}(1.0)     Gray{Float64}(1.0)

# %%
Gray.( noisyCross() ) #make a sample cross
# Out:
# 10×10 Array{Gray{Float64},2} with eltype Gray{Float64}:
#  Gray{Float64}(1.0)  Gray{Float64}(1.0)  …  Gray{Float64}(1.0)
#  Gray{Float64}(1.0)  Gray{Float64}(1.0)     Gray{Float64}(1.0)
#  Gray{Float64}(1.0)  Gray{Float64}(1.0)     Gray{Float64}(1.0)
#  Gray{Float64}(1.0)  Gray{Float64}(1.0)     Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.0)     Gray{Float64}(0.0)
#  Gray{Float64}(1.0)  Gray{Float64}(1.0)  …  Gray{Float64}(1.0)
#  Gray{Float64}(1.0)  Gray{Float64}(1.0)     Gray{Float64}(1.0)
#  Gray{Float64}(1.0)  Gray{Float64}(1.0)     Gray{Float64}(1.0)
#  Gray{Float64}(1.0)  Gray{Float64}(1.0)     Gray{Float64}(1.0)
#  Gray{Float64}(1.0)  Gray{Float64}(1.0)     Gray{Float64}(1.0)

# %%
img_Num = 100 #number of images of each type to generate
# Out:
# 100

# %%
squares = [vec(noisySquare()) for i in 1:img_Num];
crosses = [vec(noisyCross()) for i in 1:img_Num];

# %%
Gray.(squares[1])
# Out:
# 100-element Array{Gray{Float64},1} with eltype Gray{Float64}:
#  Gray{Float64}(1.0)
#  Gray{Float64}(1.0)
#  Gray{Float64}(1.0)
#  Gray{Float64}(1.0)
#  Gray{Float64}(1.0)
#  Gray{Float64}(1.0)
#  Gray{Float64}(1.0)
#  Gray{Float64}(1.0)
#  Gray{Float64}(1.0)
#  Gray{Float64}(1.0)
#  Gray{Float64}(1.0)
#  Gray{Float64}(1.0)
#  Gray{Float64}(1.0)
#  ⋮
#  Gray{Float64}(1.0)
#  Gray{Float64}(1.0)
#  Gray{Float64}(1.0)
#  Gray{Float64}(1.0)
#  Gray{Float64}(1.0)
#  Gray{Float64}(1.0)
#  Gray{Float64}(1.0)
#  Gray{Float64}(1.0)
#  Gray{Float64}(1.0)
#  Gray{Float64}(1.0)
#  Gray{Float64}(1.0)
#  Gray{Float64}(1.0)

# %%
reshape( Gray.(squares[1]) , NN , NN )
# Out:
# 10×10 Array{Gray{Float64},2} with eltype Gray{Float64}:
#  Gray{Float64}(1.0)  Gray{Float64}(1.0)  …  Gray{Float64}(1.0)
#  Gray{Float64}(1.0)  Gray{Float64}(1.0)     Gray{Float64}(1.0)
#  Gray{Float64}(1.0)  Gray{Float64}(1.0)     Gray{Float64}(1.0)
#  Gray{Float64}(1.0)  Gray{Float64}(1.0)     Gray{Float64}(1.0)
#  Gray{Float64}(1.0)  Gray{Float64}(1.0)     Gray{Float64}(1.0)
#  Gray{Float64}(1.0)  Gray{Float64}(1.0)  …  Gray{Float64}(1.0)
#  Gray{Float64}(1.0)  Gray{Float64}(1.0)     Gray{Float64}(1.0)
#  Gray{Float64}(1.0)  Gray{Float64}(1.0)     Gray{Float64}(1.0)
#  Gray{Float64}(1.0)  Gray{Float64}(1.0)     Gray{Float64}(1.0)
#  Gray{Float64}(1.0)  Gray{Float64}(1.0)     Gray{Float64}(1.0)

# %%
real_data = vcat( squares , crosses ); #real data examples

# %%
#data must be in WxHxCxN but for generator it is 1 d entry so that is WxHxCxN we reshape
tmp = Flux.stack( real_data , dims=2 )
display( size( tmp ) )
tmp = reshape( tmp , (10,10,200) )
display( size( tmp ) )
real_data_WHCN = Flux.unsqueeze( tmp , dims = 3 ) # WHCN format as needed
display( size( real_data_WHCN ) )
Gray.( real_data_WHCN[ : , : , 1 , 1 ] )
# Out:
# (100, 200)
# (10, 10, 200)
# (10, 10, 1, 200)
# 10×10 Array{Gray{Float64},2} with eltype Gray{Float64}:
#  Gray{Float64}(1.0)  Gray{Float64}(1.0)  …  Gray{Float64}(1.0)
#  Gray{Float64}(1.0)  Gray{Float64}(1.0)     Gray{Float64}(1.0)
#  Gray{Float64}(1.0)  Gray{Float64}(1.0)     Gray{Float64}(1.0)
#  Gray{Float64}(1.0)  Gray{Float64}(1.0)     Gray{Float64}(1.0)
#  Gray{Float64}(1.0)  Gray{Float64}(1.0)     Gray{Float64}(1.0)
#  Gray{Float64}(1.0)  Gray{Float64}(1.0)  …  Gray{Float64}(1.0)
#  Gray{Float64}(1.0)  Gray{Float64}(1.0)     Gray{Float64}(1.0)
#  Gray{Float64}(1.0)  Gray{Float64}(1.0)     Gray{Float64}(1.0)
#  Gray{Float64}(1.0)  Gray{Float64}(1.0)     Gray{Float64}(1.0)
#  Gray{Float64}(1.0)  Gray{Float64}(1.0)     Gray{Float64}(1.0)

# %%
real_data_labels = Int.([ ones( 100 ) ; 2*ones(100) ]); #the labels associated with the real data
display( size(real_data_labels) )
display( real_data_labels[ 1 ] )
display( real_data_labels[ end ] )
# Out:
# (200,)
# 1
# 2

# %%
latent_dim = 10
# Out:
# 10

# %%
function MakeZvectors( labels ) #make z samples with the label information concatenated
    z = rand( latent_dim , length(labels) )
    z_label = repeat( labels' , latent_dim , 1 )
    return cat( z_label , z , dims=1 ) #joint representation of the embedding of the label and noise vector z
end
# Out:
# MakeZvectors (generic function with 1 method)

# %%
MakeZvectors( [1,2,1] )
# Out:
# 20×3 Matrix{Float64}:
#  1.0        2.0       1.0
#  1.0        2.0       1.0
#  1.0        2.0       1.0
#  1.0        2.0       1.0
#  1.0        2.0       1.0
#  1.0        2.0       1.0
#  1.0        2.0       1.0
#  1.0        2.0       1.0
#  1.0        2.0       1.0
#  1.0        2.0       1.0
#  0.714414   0.71431   0.908454
#  0.222058   0.686163  0.940879
#  0.508027   0.884584  0.134282
#  0.590224   0.792088  0.0743809
#  0.343376   0.381578  0.214922
#  0.0504005  0.634793  0.624622
#  0.222904   0.345099  0.71161
#  0.108109   0.257417  0.250256
#  0.797938   0.490122  0.735825
#  0.942592   0.832766  0.274142

# %%
m_gen = Chain( 
      Dense( 2*latent_dim => 100 ) , 
      BatchNorm( 100 , relu ) ,
      x->reshape( x , 5 , 5 , 4 , : ) , #make into WHCN
      ConvTranspose( (4,4) , 4 => 2 ; stride = 1, pad = 1 ) ,
      BatchNorm( 2 , relu ) ,
      ConvTranspose( (5,5) , 2 => 1 ; stride = 1, pad = 1 ) , 
      ConvTranspose( (5,5) , 1 => 1 ; stride = 1, pad = 1 ) , 
      sigmoid
    );

# %%
m_gen( MakeZvectors( [2] ) )
# Out:
# 10×10×1×1 Array{Float64, 4}:
# [:, :, 1, 1] =
#  0.494722  0.511877  0.503216  0.458087  …  0.498718  0.515661  0.488857
#  0.55254   0.462461  0.492602  0.524159     0.539981  0.479358  0.495944
#  0.517761  0.503669  0.54791   0.477382     0.477054  0.460273  0.490166
#  0.501436  0.478374  0.493496  0.54121      0.432158  0.521224  0.531271
#  0.467368  0.539157  0.440733  0.521067     0.489567  0.533757  0.487711
#  0.514377  0.452322  0.432398  0.559934  …  0.438616  0.481678  0.398467
#  0.453079  0.471246  0.45761   0.360411     0.444233  0.43593   0.515772
#  0.462669  0.418847  0.36269   0.468803     0.456562  0.492377  0.501409
#  0.488356  0.466225  0.463999  0.425635     0.503913  0.474501  0.411419
#  0.502617  0.497165  0.489136  0.462599     0.472002  0.463373  0.524799

# %%
display( size( m_gen( MakeZvectors( [1,2,2,1] ) ) ) )
Gray.( m_gen(MakeZvectors([2]))[:,:,1,1] )
# Out:
# (10, 10, 1, 4)
# 10×10 Array{Gray{Float64},2} with eltype Gray{Float64}:
#  Gray{Float64}(0.492602)  Gray{Float64}(0.507978)  …  Gray{Float64}(0.482544)
#  Gray{Float64}(0.55258)   Gray{Float64}(0.466632)     Gray{Float64}(0.501689)
#  Gray{Float64}(0.525007)  Gray{Float64}(0.509237)     Gray{Float64}(0.50048)
#  Gray{Float64}(0.506297)  Gray{Float64}(0.469041)     Gray{Float64}(0.514732)
#  Gray{Float64}(0.454133)  Gray{Float64}(0.538714)     Gray{Float64}(0.495483)
#  Gray{Float64}(0.517606)  Gray{Float64}(0.443579)  …  Gray{Float64}(0.40465)
#  Gray{Float64}(0.459142)  Gray{Float64}(0.488593)     Gray{Float64}(0.504778)
#  Gray{Float64}(0.466091)  Gray{Float64}(0.424641)     Gray{Float64}(0.506886)
#  Gray{Float64}(0.485087)  Gray{Float64}(0.46785)      Gray{Float64}(0.423047)
#  Gray{Float64}(0.500608)  Gray{Float64}(0.498326)     Gray{Float64}(0.524108)

# %%
m_dis = Chain( #discriminator takes in 2 channel data, the pixel info in 1 and the label info on the next
      Conv( (4,4) , 2 => 2 , stride = 1 , pad = 1 ) ,
      relu ,
      Conv( (4,4) , 2 => 1 , stride = 1 , pad = 1 ) ,
      relu ,
      Flux.flatten ,
      Dense( 64 => 10 , relu ) ,
      Dense( 10 => 1 ) ,
      sigmoid
    );

# %%
m_emb = Chain( Embedding( 2=>NN*NN ), x->reshape(x,10,10,1,size(x,2)) );#2 class embedding -> number of pixels

# %%
m_emb([1]) #see the embedding of the label information
# Out:
# 10×10×1×1 Array{Float32, 4}:
# [:, :, 1, 1] =
#  -1.33792     0.873144   0.827246   …   0.360309  -0.824426    -0.647584
#  -0.112652    1.62617    1.09043        0.169871   0.912145     0.982686
#  -0.0836154   0.404633  -1.40741        0.37268   -0.140749    -0.139589
#  -0.0947054   0.228917   0.79277       -1.26936    0.00115312  -1.96058
#   0.697565   -0.736339   1.18896        0.471314  -0.212622     0.491869
#  -0.824471   -1.24399    2.20797    …  -1.73156   -1.8465      -0.877971
#   0.136777   -1.41554    0.627199       0.711676  -0.945379    -0.327938
#  -1.66357     0.270233   0.0145742     -1.04038    0.884851    -0.500464
#   0.279103    2.0871    -0.668557      -0.863415   0.354229    -0.356351
#  -0.304541   -0.155848   0.192133      -0.260493   0.0768745   -0.172632

# %%
cat( m_gen(MakeZvectors([2])) , m_emb([1]) , dims=3 ) #do the channel data augmentation
# Out:
# 10×10×2×1 Array{Float64, 4}:
# [:, :, 1, 1] =
#  0.494534  0.508167  0.505124  0.463651  …  0.503881  0.511152  0.486958
#  0.548213  0.464614  0.495788  0.513455     0.518383  0.499535  0.492626
#  0.521413  0.512083  0.529528  0.494767     0.476374  0.45381   0.50447
#  0.505398  0.468093  0.486997  0.552833     0.458804  0.508494  0.513743
#  0.458393  0.545291  0.425632  0.531742     0.494028  0.53713   0.477907
#  0.517318  0.461612  0.418789  0.5929    …  0.443945  0.475854  0.426629
#  0.461633  0.48976   0.467089  0.370086     0.483371  0.449383  0.512082
#  0.466383  0.431313  0.354772  0.459213     0.444281  0.499785  0.501123
#  0.483868  0.464845  0.459354  0.431223     0.50103   0.474971  0.428765
#  0.499614  0.49717   0.490891  0.464254     0.467256  0.461544  0.525685
#
# [:, :, 2, 1] =
#  -1.33792     0.873144   0.827246   …   0.360309  -0.824426    -0.647584
#  -0.112652    1.62617    1.09043        0.169871   0.912145     0.982686
#  -0.0836154   0.404633  -1.40741        0.37268   -0.140749    -0.139589
#  -0.0947054   0.228917   0.79277       -1.26936    0.00115312  -1.96058
#   0.697565   -0.736339   1.18896        0.471314  -0.212622     0.491869
#  -0.824471   -1.24399    2.20797    …  -1.73156   -1.8465      -0.877971
#   0.136777   -1.41554    0.627199       0.711676  -0.945379    -0.327938
#  -1.66357     0.270233   0.0145742     -1.04038    0.884851    -0.500464
#   0.279103    2.0871    -0.668557      -0.863415   0.354229    -0.356351
#  -0.304541   -0.155848   0.192133      -0.260493   0.0768745   -0.172632

# %%
labels_tmp = [1,2,1,2]
display( size( cat( m_gen( MakeZvectors(labels_tmp)) , m_emb(labels_tmp) , dims=3 ) ) ) #check size
m_dis( cat( m_gen( MakeZvectors(labels_tmp)) , m_emb(labels_tmp) , dims=3 ) ) #check discriminator output
# Out:
# (10, 10, 2, 4)
# 1×4 Matrix{Float64}:
#  0.482967  0.498981  0.483266  0.498953

# %%
inds_tmp = [1,50,150,200]
labels_tmp = real_data_labels[ inds_tmp ]
m_dis( cat( real_data_WHCN[:,:,:,inds_tmp] , m_emb(labels_tmp) , dims=3 ) ) #feeding real data
# Out:
# 1×4 Matrix{Float64}:
#  0.475752  0.4824  0.491254  0.500517

# %%
function generator_loss( fake_output ) 
    Flux.logitbinarycrossentropy( fake_output , 1 )
end
function discriminator_loss( real_output , fake_output )
    real_loss = Flux.logitbinarycrossentropy( real_output , 1 )
    fake_loss = Flux.logitbinarycrossentropy( fake_output , 0 )
    return real_loss + fake_loss
end
# Out:
# discriminator_loss (generic function with 1 method)

# %%
function train_generator( gen , dscr , emb , opt_gen , labels )
    loss, grads = Flux.withgradient( gen ) do gen
        dis_output = dscr( cat( gen( MakeZvectors(labels)) , emb(labels) , dims=3 ) )
        generator_loss( dis_output )        
    end
    Flux.update!( opt_gen , gen , grads[1] )
    return loss
end
# Out:
# train_generator (generic function with 1 method)

# %%
function train_discriminator( gen , dscr , emb , x , opt_dscr , labels )
    gen_output = cat( gen( MakeZvectors(labels)) , emb(labels) , dims=3 )
    real_output = cat( x , emb(labels) , dims=3 )
    loss, grads = Flux.withgradient(dscr) do dscr        
        discriminator_loss( dscr( real_output ) , dscr( gen_output ) )
    end
    Flux.update!( opt_dscr , dscr , grads[1] )
    return loss
end
# Out:
# train_discriminator (generic function with 1 method)

# %%
opt_dis = Flux.setup( Adam( 0.0002 ) , m_dis )
opt_gen = Flux.setup( Adam( 0.0002) , m_gen );

# %%
display( train_discriminator( m_gen , m_dis , m_emb , real_data_WHCN[:,:,:,1:2] , opt_dis , [1,1] ) )
display( train_generator( m_gen , m_dis , m_emb , opt_gen , [1,2] ) )
# Out:
# 1.4466288078958343
# 0.4768019360355424

# %%
loss_dis_array = []
loss_gen_array = []
# Out:
# Any[]

# %%
batch_num = 10

for epoch in 1:20000
    tmp_inds = Random.randperm(length(real_data_labels))[1:batch_num]
    labels_tmp = real_data_labels[ tmp_inds ]
    
    x_real_tmp = real_data_WHCN[:,:,:,tmp_inds]
            
    loss_dis = train_discriminator( m_gen , m_dis , m_emb , x_real_tmp , opt_dis , labels_tmp )
    push!( loss_dis_array , loss_dis )
    loss_gen = train_generator( m_gen , m_dis , m_emb , opt_gen , labels_tmp )
    push!( loss_gen_array , loss_gen )
end

# %%
p_dis = plot( loss_dis_array , title="discriminator loss" )
p_gen = plot( loss_gen_array , title="generator loss" )
plot( p_dis , p_gen )

# %%
inds_tmp = [1,50,150,200]
labels_tmp = real_data_labels[ inds_tmp ]
m_dis( cat( real_data_WHCN[:,:,:,inds_tmp] , m_emb(labels_tmp) , dims=3 ) ) #feeding real data
# Out:
# 1×4 Matrix{Float64}:
#  8.78116e-20  9.68221e-17  1.0  1.0

# %%
labels_tmp = [1,2,1,2]
display( m_dis( cat( m_gen( MakeZvectors(labels_tmp)) , m_emb(labels_tmp) , dims=3 ) ) ) #check discriminator output
# Out:
# 1×4 Matrix{Float64}:
#  8.32016e-8  1.66002e-14  8.34582e-8  6.03976e-15

# %%
Gray.(m_gen( MakeZvectors(labels_tmp))[:,:,1,1])
# Out:
# 10×10 Array{Gray{Float64},2} with eltype Gray{Float64}:
#  Gray{Float64}(0.999513)  …  Gray{Float64}(0.984778)
#  Gray{Float64}(1.0)          Gray{Float64}(0.936914)
#  Gray{Float64}(1.0)          Gray{Float64}(0.998169)
#  Gray{Float64}(1.0)          Gray{Float64}(0.999989)
#  Gray{Float64}(1.0)          Gray{Float64}(0.911323)
#  Gray{Float64}(1.0)       …  Gray{Float64}(0.958032)
#  Gray{Float64}(1.0)          Gray{Float64}(0.998744)
#  Gray{Float64}(1.0)          Gray{Float64}(0.998198)
#  Gray{Float64}(1.0)          Gray{Float64}(0.0944037)
#  Gray{Float64}(0.999998)     Gray{Float64}(0.993719)

# %%
Gray.(m_gen( MakeZvectors(labels_tmp))[:,:,1,4])
# Out:
# 10×10 Array{Gray{Float64},2} with eltype Gray{Float64}:
#  Gray{Float64}(0.999873)    …  Gray{Float64}(0.987237)
#  Gray{Float64}(0.00908226)     Gray{Float64}(0.989698)
#  Gray{Float64}(0.991074)       Gray{Float64}(0.999572)
#  Gray{Float64}(0.997733)       Gray{Float64}(0.999948)
#  Gray{Float64}(0.996455)       Gray{Float64}(0.999499)
#  Gray{Float64}(0.999431)    …  Gray{Float64}(0.9969)
#  Gray{Float64}(0.864469)       Gray{Float64}(0.64369)
#  Gray{Float64}(0.919981)       Gray{Float64}(0.923645)
#  Gray{Float64}(0.908725)       Gray{Float64}(0.828425)
#  Gray{Float64}(0.890149)       Gray{Float64}(0.506176)

# %%
#############################################3
