# %%
using Images, TestImages, ImageIO, ImageMagick, ImageView, Colors
using StatsBase, Statistics, LinearAlgebra, Plots, Random
using Flux

# %%
NN = 10 #side length of images generated

function noisySquare() #make a 'noisy' square image
    newPic = ones(NN,NN)
    for rr = 1:NN
        for cc = 1:NN
            if( (rr >= 3 && rr <= 7) && (cc >= 3 && cc <= 7) )
                if( rand() >= 0.1 ) newPic[rr,cc] = 0 end
            end
        end
    end
    return newPic
end

function noisyCross() #function 'noisy cross' image generator
    newPic = ones(NN,NN)
    for rr = 1:NN
        for cc = 1:NN
            if( rr == 5 || cc == 5 )
                if( rand() >= 0.1 ) newPic[rr,cc] = 0 end
            end
        end
    end
    return newPic
end
# Out:
# noisyCross (generic function with 1 method)

# %%
Gray.( noisySquare() ) #make a sample noisy square
# Out:
# 10×10 Array{Gray{Float64},2} with eltype Gray{Float64}:
#  Gray{Float64}(1.0)  Gray{Float64}(1.0)  …  Gray{Float64}(1.0)
#  Gray{Float64}(1.0)  Gray{Float64}(1.0)     Gray{Float64}(1.0)
#  Gray{Float64}(1.0)  Gray{Float64}(1.0)     Gray{Float64}(1.0)
#  Gray{Float64}(1.0)  Gray{Float64}(1.0)     Gray{Float64}(1.0)
#  Gray{Float64}(1.0)  Gray{Float64}(1.0)     Gray{Float64}(1.0)
#  Gray{Float64}(1.0)  Gray{Float64}(1.0)  …  Gray{Float64}(1.0)
#  Gray{Float64}(1.0)  Gray{Float64}(1.0)     Gray{Float64}(1.0)
#  Gray{Float64}(1.0)  Gray{Float64}(1.0)     Gray{Float64}(1.0)
#  Gray{Float64}(1.0)  Gray{Float64}(1.0)     Gray{Float64}(1.0)
#  Gray{Float64}(1.0)  Gray{Float64}(1.0)     Gray{Float64}(1.0)

# %%
Gray.( noisyCross() ) #make a sample cross
# Out:
# 10×10 Array{Gray{Float64},2} with eltype Gray{Float64}:
#  Gray{Float64}(1.0)  Gray{Float64}(1.0)  …  Gray{Float64}(1.0)
#  Gray{Float64}(1.0)  Gray{Float64}(1.0)     Gray{Float64}(1.0)
#  Gray{Float64}(1.0)  Gray{Float64}(1.0)     Gray{Float64}(1.0)
#  Gray{Float64}(1.0)  Gray{Float64}(1.0)     Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.0)     Gray{Float64}(0.0)
#  Gray{Float64}(1.0)  Gray{Float64}(1.0)  …  Gray{Float64}(1.0)
#  Gray{Float64}(1.0)  Gray{Float64}(1.0)     Gray{Float64}(1.0)
#  Gray{Float64}(1.0)  Gray{Float64}(1.0)     Gray{Float64}(1.0)
#  Gray{Float64}(1.0)  Gray{Float64}(1.0)     Gray{Float64}(1.0)
#  Gray{Float64}(1.0)  Gray{Float64}(1.0)     Gray{Float64}(1.0)

# %%
img_Num = 100 #number of images of each type to generate
# Out:
# 100

# %%
squares = [vec(noisySquare()) for i in 1:img_Num];
crosses = [vec(noisyCross()) for i in 1:img_Num];

# %%
Gray.(squares[1])
# Out:
# 100-element Array{Gray{Float64},1} with eltype Gray{Float64}:
#  Gray{Float64}(1.0)
#  Gray{Float64}(1.0)
#  Gray{Float64}(1.0)
#  Gray{Float64}(1.0)
#  Gray{Float64}(1.0)
#  Gray{Float64}(1.0)
#  Gray{Float64}(1.0)
#  Gray{Float64}(1.0)
#  Gray{Float64}(1.0)
#  Gray{Float64}(1.0)
#  Gray{Float64}(1.0)
#  Gray{Float64}(1.0)
#  Gray{Float64}(1.0)
#  ⋮
#  Gray{Float64}(1.0)
#  Gray{Float64}(1.0)
#  Gray{Float64}(1.0)
#  Gray{Float64}(1.0)
#  Gray{Float64}(1.0)
#  Gray{Float64}(1.0)
#  Gray{Float64}(1.0)
#  Gray{Float64}(1.0)
#  Gray{Float64}(1.0)
#  Gray{Float64}(1.0)
#  Gray{Float64}(1.0)
#  Gray{Float64}(1.0)

# %%
reshape( Gray.(squares[1]) , NN , NN )
# Out:
# 10×10 Array{Gray{Float64},2} with eltype Gray{Float64}:
#  Gray{Float64}(1.0)  Gray{Float64}(1.0)  …  Gray{Float64}(1.0)
#  Gray{Float64}(1.0)  Gray{Float64}(1.0)     Gray{Float64}(1.0)
#  Gray{Float64}(1.0)  Gray{Float64}(1.0)     Gray{Float64}(1.0)
#  Gray{Float64}(1.0)  Gray{Float64}(1.0)     Gray{Float64}(1.0)
#  Gray{Float64}(1.0)  Gray{Float64}(1.0)     Gray{Float64}(1.0)
#  Gray{Float64}(1.0)  Gray{Float64}(1.0)  …  Gray{Float64}(1.0)
#  Gray{Float64}(1.0)  Gray{Float64}(1.0)     Gray{Float64}(1.0)
#  Gray{Float64}(1.0)  Gray{Float64}(1.0)     Gray{Float64}(1.0)
#  Gray{Float64}(1.0)  Gray{Float64}(1.0)     Gray{Float64}(1.0)
#  Gray{Float64}(1.0)  Gray{Float64}(1.0)     Gray{Float64}(1.0)

# %%
real_data = vcat( squares , crosses ); #real data examples

# %%
#data must be in WxHxCxN but for generator it is 1 d entry so that is WxHxCxN we reshape
tmp = Flux.stack( real_data , dims=2 )
display( size( tmp ) )
tmp = reshape( tmp , (10,10,200) )
display( size( tmp ) )
real_data_WHCN = Flux.unsqueeze( tmp , dims = 3 ) # WHCN format as needed
display( size( real_data_WHCN ) )
Gray.( real_data_WHCN[ : , : , 1 , 1 ] )
# Out:
# (100, 200)
# (10, 10, 200)
# (10, 10, 1, 200)
# 10×10 Array{Gray{Float64},2} with eltype Gray{Float64}:
#  Gray{Float64}(1.0)  Gray{Float64}(1.0)  …  Gray{Float64}(1.0)
#  Gray{Float64}(1.0)  Gray{Float64}(1.0)     Gray{Float64}(1.0)
#  Gray{Float64}(1.0)  Gray{Float64}(1.0)     Gray{Float64}(1.0)
#  Gray{Float64}(1.0)  Gray{Float64}(1.0)     Gray{Float64}(1.0)
#  Gray{Float64}(1.0)  Gray{Float64}(1.0)     Gray{Float64}(1.0)
#  Gray{Float64}(1.0)  Gray{Float64}(1.0)  …  Gray{Float64}(1.0)
#  Gray{Float64}(1.0)  Gray{Float64}(1.0)     Gray{Float64}(1.0)
#  Gray{Float64}(1.0)  Gray{Float64}(1.0)     Gray{Float64}(1.0)
#  Gray{Float64}(1.0)  Gray{Float64}(1.0)     Gray{Float64}(1.0)
#  Gray{Float64}(1.0)  Gray{Float64}(1.0)     Gray{Float64}(1.0)

# %%
real_data_labels = Int.([ ones( 100 ) ; 2*ones(100) ]); #the labels associated with the real data
display( size(real_data_labels) )
display( real_data_labels[ 1 ] )
display( real_data_labels[ end ] )
# Out:
# (200,)
# 1
# 2

# %%
latent_dim = 10
# Out:
# 10

# %%
function MakeZvectors( labels ) #make z samples with the label information concatenated
    z = rand( latent_dim , length(labels) )
    z_label = repeat( labels' , latent_dim , 1 )
    return cat( z_label , z , dims=1 ) #joint representation of the embedding of the label and noise vector z
end
# Out:
# MakeZvectors (generic function with 1 method)

# %%
MakeZvectors( [1,2,1] ) #look at the representation of latent z and the label information
# Out:
# 20×3 Matrix{Float64}:
#  1.0        2.0       1.0
#  1.0        2.0       1.0
#  1.0        2.0       1.0
#  1.0        2.0       1.0
#  1.0        2.0       1.0
#  1.0        2.0       1.0
#  1.0        2.0       1.0
#  1.0        2.0       1.0
#  1.0        2.0       1.0
#  1.0        2.0       1.0
#  0.396365   0.198291  0.125593
#  0.391532   0.983043  0.430282
#  0.24635    0.856699  0.770755
#  0.510871   0.136046  0.193565
#  0.339431   0.575276  0.288021
#  0.391112   0.12257   0.917426
#  0.901898   0.417369  0.183283
#  0.0338594  0.771401  0.00834931
#  0.244516   0.778027  0.536678
#  0.599847   0.390016  0.700621

# %%
m_gen = Chain( 
      Dense( 2*latent_dim => 100 ) , 
      BatchNorm( 100 , relu ) ,
      x->reshape( x , 5 , 5 , 4 , : ) , #make into WHCN
      ConvTranspose( (4,4) , 4 => 2 ; stride = 1, pad = 1 ) ,
      BatchNorm( 2 , relu ) ,
      ConvTranspose( (5,5) , 2 => 1 ; stride = 1, pad = 1 ) , 
      ConvTranspose( (5,5) , 1 => 1 ; stride = 1, pad = 1 ) , 
      sigmoid
    );

# %%
m_gen( MakeZvectors( [2] ) )
# Out:
# 10×10×1×1 Array{Float64, 4}:
# [:, :, 1, 1] =
#  0.484008  0.474836  0.531646  0.520868  …  0.504297  0.500569  0.491104
#  0.522508  0.517434  0.447412  0.540631     0.540568  0.487471  0.481919
#  0.501432  0.498808  0.507089  0.377232     0.485296  0.472724  0.506605
#  0.532522  0.475508  0.431608  0.490616     0.408186  0.513671  0.519556
#  0.465788  0.477176  0.531356  0.585235     0.469242  0.505367  0.480042
#  0.49103   0.518568  0.507975  0.543131  …  0.557508  0.494508  0.490145
#  0.520818  0.501244  0.518588  0.597086     0.539604  0.47624   0.527132
#  0.503279  0.483645  0.519998  0.383754     0.481658  0.474217  0.504252
#  0.498965  0.527927  0.468566  0.446097     0.509783  0.503943  0.480729
#  0.500429  0.512113  0.488052  0.494862     0.52219   0.525374  0.510726

# %%
display( size( m_gen( MakeZvectors( [1,2,2,1] ) ) ) )
Gray.( m_gen(MakeZvectors([2]))[:,:,1,1] )
# Out:
# (10, 10, 1, 4)
# 10×10 Array{Gray{Float64},2} with eltype Gray{Float64}:
#  Gray{Float64}(0.484107)  Gray{Float64}(0.482993)  …  Gray{Float64}(0.484307)
#  Gray{Float64}(0.529269)  Gray{Float64}(0.519443)     Gray{Float64}(0.483727)
#  Gray{Float64}(0.489893)  Gray{Float64}(0.509478)     Gray{Float64}(0.512104)
#  Gray{Float64}(0.532521)  Gray{Float64}(0.473777)     Gray{Float64}(0.517944)
#  Gray{Float64}(0.461441)  Gray{Float64}(0.456352)     Gray{Float64}(0.470061)
#  Gray{Float64}(0.487574)  Gray{Float64}(0.521955)  …  Gray{Float64}(0.495478)
#  Gray{Float64}(0.527474)  Gray{Float64}(0.499431)     Gray{Float64}(0.533199)
#  Gray{Float64}(0.503157)  Gray{Float64}(0.49174)      Gray{Float64}(0.506559)
#  Gray{Float64}(0.496844)  Gray{Float64}(0.531059)     Gray{Float64}(0.477695)
#  Gray{Float64}(0.499566)  Gray{Float64}(0.510721)     Gray{Float64}(0.507422)

# %%
m_dis = Chain( #discriminator takes in 2 channel data, the pixel info in 1 and the label info on the next
      Conv( (4,4) , 2 => 2 , stride = 1 , pad = 1 ) ,
      relu ,
      Conv( (4,4) , 2 => 1 , stride = 1 , pad = 1 ) ,
      relu ,
      Flux.flatten ,
      Dense( 64 => 10 , relu ) ,
      Dense( 10 => 1 ) ,
      sigmoid
    );

# %%
m_emb = Chain( Embedding( 2=>NN*NN ), x->reshape(x,10,10,1,size(x,2)) );#2 class embedding -> number of pixels

# %%
m_emb([1]) #see the embedding of the label information
# Out:
# 10×10×1×1 Array{Float32, 4}:
# [:, :, 1, 1] =
#   1.22038   -1.97733     1.18646   -0.51422    …   0.877418     0.0905503
#   0.88398    1.20823    -0.699154  -0.185205       0.160742     0.687286
#  -0.933337   0.230381    0.534267   0.246802       0.0863558   -0.563027
#   0.709184   0.688181   -1.0741     0.0544382     -1.00142     -0.0177069
#  -0.323042   0.0114211  -1.3832     0.579852       0.228551     0.941386
#  -0.482404  -0.426845   -0.566683   0.410199   …  -0.393797    -0.423933
#   0.581052   1.11877     0.575838   0.545646      -0.0221601    0.901017
#   0.904468  -0.685419   -0.454734   1.49241       -0.631698    -0.164692
#  -1.37115    1.79448     0.277861   2.20367       -2.38701     -0.946519
#  -1.01423    1.31526     0.632896  -0.329355      -0.00885953  -0.468097

# %%
cat( m_gen(MakeZvectors([2])) , m_emb([1]) , dims=3 ) #do the channel data augmentation
# Out:
# 10×10×2×1 Array{Float64, 4}:
# [:, :, 1, 1] =
#  0.483077  0.475647  0.526759  0.521931  …  0.509507  0.502399  0.488788
#  0.529754  0.523534  0.442871  0.526527     0.538568  0.496118  0.495393
#  0.490897  0.502492  0.51981   0.382481     0.49991   0.487039  0.50989
#  0.536674  0.46144   0.429042  0.509792     0.430242  0.498157  0.502664
#  0.459182  0.468982  0.54524   0.606895     0.47458   0.492955  0.467073
#  0.487179  0.526588  0.509327  0.510798  …  0.522276  0.511385  0.501209
#  0.529069  0.500764  0.526713  0.595961     0.537884  0.482897  0.542818
#  0.501394  0.495544  0.508912  0.376036     0.487487  0.462464  0.51166
#  0.498699  0.524941  0.462515  0.458907     0.507958  0.494487  0.469022
#  0.501211  0.506106  0.484788  0.495741     0.517852  0.524151  0.507084
#
# [:, :, 2, 1] =
#   1.22038   -1.97733     1.18646   -0.51422    …   0.877418     0.0905503
#   0.88398    1.20823    -0.699154  -0.185205       0.160742     0.687286
#  -0.933337   0.230381    0.534267   0.246802       0.0863558   -0.563027
#   0.709184   0.688181   -1.0741     0.0544382     -1.00142     -0.0177069
#  -0.323042   0.0114211  -1.3832     0.579852       0.228551     0.941386
#  -0.482404  -0.426845   -0.566683   0.410199   …  -0.393797    -0.423933
#   0.581052   1.11877     0.575838   0.545646      -0.0221601    0.901017
#   0.904468  -0.685419   -0.454734   1.49241       -0.631698    -0.164692
#  -1.37115    1.79448     0.277861   2.20367       -2.38701     -0.946519
#  -1.01423    1.31526     0.632896  -0.329355      -0.00885953  -0.468097

# %%
labels_tmp = [1,2,1,2]
display( size( cat( m_gen( MakeZvectors(labels_tmp)) , m_emb(labels_tmp) , dims=3 ) ) ) #check size
m_dis( cat( m_gen( MakeZvectors(labels_tmp)) , m_emb(labels_tmp) , dims=3 ) ) #check discriminator output
# Out:
# (10, 10, 2, 4)
# 1×4 Matrix{Float64}:
#  0.429184  0.521005  0.429017  0.521429

# %%
inds_tmp = [1,50,150,200]
labels_tmp = real_data_labels[ inds_tmp ]
m_dis( cat( real_data_WHCN[:,:,:,inds_tmp] , m_emb(labels_tmp) , dims=3 ) ) #feeding real data
# Out:
# 1×4 Matrix{Float64}:
#  0.441266  0.432745  0.457276  0.463926

# %%
function generator_loss( fake_output ) 
    Flux.logitbinarycrossentropy( fake_output , 1 )
end
function discriminator_loss( real_output , fake_output )
    real_loss = Flux.logitbinarycrossentropy( real_output , 1 )
    fake_loss = Flux.logitbinarycrossentropy( fake_output , 0 )
    return real_loss + fake_loss
end
# Out:
# discriminator_loss (generic function with 1 method)

# %%
function train_generator( gen , dscr , emb , opt_gen , labels )
    loss, grads = Flux.withgradient( gen ) do gen
        dis_output = dscr( cat( gen( MakeZvectors(labels)) , emb(labels) , dims=3 ) )
        generator_loss( dis_output )        
    end
    Flux.update!( opt_gen , gen , grads[1] )
    return loss
end
# Out:
# train_generator (generic function with 1 method)

# %%
function train_discriminator( gen , dscr , emb , x , opt_dscr , opt_emb , labels )
    gen_output = cat( gen( MakeZvectors(labels)) , emb(labels) , dims=3 )
    real_output = cat( x , emb(labels) , dims=3 )
    loss, grads = Flux.withgradient(dscr,emb) do dscr,emb #train the discriminator and embedding
        discriminator_loss( dscr( real_output ) , dscr( gen_output ) )
    end
    Flux.update!( (opt_dscr,opt_emb) , (dscr,emb) , grads ) #update parameters of both disc and emb
    return loss
end
# Out:
# train_discriminator (generic function with 2 methods)

# %%
opt_dis = Flux.setup( Adam( 0.0002 ) , m_dis );
opt_gen = Flux.setup( Adam( 0.0002 ) , m_gen );
opt_emb = Flux.setup( Adam( 0.0002 ) , m_emb );

# %%
display( train_discriminator( m_gen , m_dis , m_emb , real_data_WHCN[:,:,:,1:2] , opt_dis , opt_emb , [1,1] ) )
display( train_generator( m_gen , m_dis , m_emb , opt_gen , [1,2] ) )
# Out:
# 1.429815667577932
# 0.48785071221283427

# %%
loss_dis_array = []
loss_gen_array = []
# Out:
# Any[]

# %%
batch_num = 10

for epoch in 1:10000
    
    tmp_inds = Random.randperm(length(real_data_labels))[1:batch_num]
    labels_tmp = real_data_labels[ tmp_inds ]
    
    x_real_tmp = real_data_WHCN[:,:,:,tmp_inds]
            
    loss_dis = train_discriminator( m_gen , m_dis , m_emb , x_real_tmp , opt_dis , labels_tmp )
    push!( loss_dis_array , loss_dis )
    
    loss_gen = train_generator( m_gen , m_dis , m_emb , opt_gen , labels_tmp )
    push!( loss_gen_array , loss_gen )
    
end

# %%
p_dis = plot( loss_dis_array , title="discriminator loss" )
p_gen = plot( loss_gen_array , title="generator loss" )
plot( p_dis , p_gen )

# %%
inds_tmp = [1,50,150,200]
labels_tmp = real_data_labels[ inds_tmp ]
m_dis( cat( real_data_WHCN[:,:,:,inds_tmp] , m_emb(labels_tmp) , dims=3 ) ) #feeding real data
# Out:
# 1×4 Matrix{Float64}:
#  0.0296588  0.0324338  0.890388  0.998297

# %%
labels_tmp = [1,2,1,2]
display( m_dis( cat( m_gen( MakeZvectors(labels_tmp)) , m_emb(labels_tmp) , dims=3 ) ) ) #check discriminator output
# Out:
# 1×4 Matrix{Float64}:
#  0.018625  0.00613756  0.0190046  0.00816845

# %%
Gray.(m_gen( MakeZvectors(labels_tmp))[:,:,1,1])
# Out:
# 10×10 Array{Gray{Float64},2} with eltype Gray{Float64}:
#  Gray{Float64}(1.0)  Gray{Float64}(1.0)       …  Gray{Float64}(0.752271)
#  Gray{Float64}(1.0)  Gray{Float64}(1.0)          Gray{Float64}(0.9988)
#  Gray{Float64}(1.0)  Gray{Float64}(0.999999)     Gray{Float64}(0.999977)
#  Gray{Float64}(1.0)  Gray{Float64}(1.0)          Gray{Float64}(0.999963)
#  Gray{Float64}(1.0)  Gray{Float64}(1.0)          Gray{Float64}(0.999894)
#  Gray{Float64}(1.0)  Gray{Float64}(1.0)       …  Gray{Float64}(1.0)
#  Gray{Float64}(1.0)  Gray{Float64}(0.999997)     Gray{Float64}(0.999984)
#  Gray{Float64}(1.0)  Gray{Float64}(1.0)          Gray{Float64}(0.999995)
#  Gray{Float64}(1.0)  Gray{Float64}(1.0)          Gray{Float64}(0.998576)
#  Gray{Float64}(1.0)  Gray{Float64}(1.0)          Gray{Float64}(0.996107)

# %%
Gray.(m_gen( MakeZvectors(labels_tmp))[:,:,1,4])
# Out:
# 10×10 Array{Gray{Float64},2} with eltype Gray{Float64}:
#  Gray{Float64}(0.911536)    …  Gray{Float64}(0.974976)
#  Gray{Float64}(0.967194)       Gray{Float64}(0.997935)
#  Gray{Float64}(0.99598)        Gray{Float64}(0.987586)
#  Gray{Float64}(0.983923)       Gray{Float64}(0.985799)
#  Gray{Float64}(6.06942e-5)     Gray{Float64}(0.0217695)
#  Gray{Float64}(0.763531)    …  Gray{Float64}(0.83322)
#  Gray{Float64}(0.99995)        Gray{Float64}(0.997951)
#  Gray{Float64}(0.999869)       Gray{Float64}(1.0)
#  Gray{Float64}(0.993714)       Gray{Float64}(0.996789)
#  Gray{Float64}(0.99817)        Gray{Float64}(0.998698)

# %%
#############################################3
