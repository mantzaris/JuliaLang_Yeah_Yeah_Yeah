# %%
using Plots
using Shapefile
using Images, ImageMagick
using StatsBase
using Distances
using Statistics

# %%
#import Pkg; Pkg.add("Images")
#import Pkg; Pkg.add("GMT")

# %% [markdown]
# ### <span style="color:orange"> **display("image/png", pp)** will reduce the size of the plots from SVG to png that compresses to make sure the notebook size does not explode</span>

# %%
dir_local = pwd()
dir_local = dir_local * "/fileMapStuff/"
# Out:
# "/home/tasty/Documents/repos/JuliaPlottingExploration/Plotting/fileMapStuff/"

# %%
file_SHP = dir_local * "Coastline.shp"
#file_DBF = 0# dir_local * "Coastline.dbf"
# Out:
# "/home/tasty/Documents/repos/JuliaPlottingExploration/Plotting/fileMapStuff/Coastline.shp"

# %% [markdown]
# ### <span style="color:orange">What are **shape files (.shp)**?</span>
#
# Geographic features in a shapefile can be represented by points, lines, or polygons (areas). It is a common spatial data format developed by ESRI. (from wikipedia) 'The shapefile format can spatially describe vector features: points, lines, and polygons, representing, for example, water wells, rivers, and lakes. (Filename extensions:	.shp, .shx, .dbf)'
# This format consists of 3 primary files with the same name, but the following file extensions:
#
# - .shp - shape format; the feature geometry itself. ( main file (.shp) contains the geometry data)
# - .dbf - shape index format; a positional index of the feature geometry to allow seeking forwards and backwards quickly (stores the attributes for each shape)
# - .shx - attribute format; columnar attributes for each shape, in dBase IV format (the index contains positional index of the feature geometry)
#
# The term "shapefile" is quite common, but the format consists of a collection of files with a common filename prefix, stored in the same directory. The three mandatory files have filename extensions .shp, .shx, and .dbf. The actual shapefile relates specifically to the .shp file, but alone is incomplete for distribution as the other supporting files are required.
#
#
# From https://www.gislounge.com/what-is-a-shapefile/: *Despite its name indicating a singular file, a shapefile is actually a collection of at least three basic files: .shp, .shx and .dbf.  All three files must be present in the same directory for them to be viewable.  There may be additional files such as a .prj with the shapefile’s projection information.  Commonly, shapefiles are compressed in a .zip file for transfer such as emailing as an attachment or via a web site download. All shapefile files must have the same name but have different extensions.  There are three required files that, at a minimum, make up a shapefile.  For example, a water GIS data set must have the minimum set of files: water.shp, water.shx, and water.dbf*

# %%
#create the map view of the objects
shapeFileURL = file_SHP
tbl = Shapefile.Table(shapeFileURL)
shp = Shapefile.shapes(Shapefile.Table(shapeFileURL))
pp=plot(shp,xrotation=45,xtickfontsize=12,
            ytickfontsize=12)
title!("Hawaii") 
xlabel!("longitude",guidefontsize=14)
ylabel!("latitude",guidefontsize=14)
display("image/png", pp)

# %%
#add annotations of sonobuoys

pp=plot(shp,xrotation=45,xtickfontsize=12,
            ytickfontsize=12)
title!("Hawaii")
xlabel!("longitude",guidefontsize=14)
ylabel!("latitude",guidefontsize=14)

pp=scatter!(pp,[-158,-159,-156],[20,21,21.5],marker=:star8,markersize=10,lab=["Sharks!"])
pp=annotate!(pp,[-158,-159,-156],[20.2,21.2,21.7],"Shark!", :black)

display("image/png", pp)

# %%
#add annotations 

pp=plot(shp,xrotation=45,xtickfontsize=12,
            ytickfontsize=12,legend=false,label="",xlim=[-161,-153])
title!("Hawaii")
xlabel!("longitude",guidefontsize=14)
ylabel!("latitude",guidefontsize=14)

pp=scatter!(pp,[-158,-159,-156],[20,21,21.5],marker=:star8,markersize=10,label="Sharks!",
    legend=:topright)

pp=scatter!(pp,[-160.1,-157],[21.1,19.8],marker=:circle,color=:blue,markersize=10,
    legendfontsize=12,label="Whales")
display("image/png", pp)

# %% [markdown]
# ### <span style="color:orange">iGISmap data for Florida</span>
#
# [link](https://www.igismap.com/florida-gis-data-shapefile-administrative-boundary-polygon-county-highway-line-map/)

# %%
dir_local = pwd()
dir_local = dir_local * "/united_states_florida_administrative_boundaries_polygon/"
# Out:
# "/home/tasty/Documents/repos/JuliaPlottingExploration/Plotting/united_states_florida_administrative_boundaries_polygon/"

# %%
file_SHP = dir_local * "united_states_florida_administrative_boundaries_polygon.shp"
# Out:
# "/home/tasty/Documents/repos/JuliaPlottingExploration/Plotting/united_states_florida_administrative_boundaries_polygon/united_states_florida_administrative_boundaries_polygon.shp"

# %%
#create the map view of the objects
shapeFileURL = file_SHP
tbl = Shapefile.Table(shapeFileURL)
shp = Shapefile.shapes(Shapefile.Table(shapeFileURL))
pp=plot(shp,xrotation=45,xtickfontsize=12,
            ytickfontsize=12)
title!("Florida and the counties") 
xlabel!("longitude",guidefontsize=14)
ylabel!("latitude",guidefontsize=14)
display("image/png", pp)

# %% [markdown]
# ### <span style="color:orange">Florida and county subdivisions</span>
#
# [link to data](https://catalog.data.gov/dataset/tiger-line-shapefile-2017-state-florida-current-county-subdivision-state-based)

# %%
dir_local = pwd()
dir_local = dir_local * "/tl_2017_12_cousub/"
# Out:
# "/home/tasty/Documents/repos/JuliaPlottingExploration/Plotting/tl_2017_12_cousub/"

# %%
file_SHP = dir_local * "tl_2017_12_cousub.shp"
# Out:
# "/home/tasty/Documents/repos/JuliaPlottingExploration/Plotting/tl_2017_12_cousub/tl_2017_12_cousub.shp"

# %%
#create the map view of the objects
shapeFileURL = file_SHP
tbl = Shapefile.Table(shapeFileURL)
shp = Shapefile.shapes(Shapefile.Table(shapeFileURL))
pp=plot(shp,xrotation=45,xtickfontsize=12,
            ytickfontsize=12)
title!("Florida and the counties") 
xlabel!("longitude",guidefontsize=14)
ylabel!("latitude",guidefontsize=14)
display("image/png", pp)

# %%
#add annotation
shapeFileURL = file_SHP
tbl = Shapefile.Table(shapeFileURL)
shp = Shapefile.shapes(Shapefile.Table(shapeFileURL))
pp=plot(shp,xrotation=45,xtickfontsize=12,
            ytickfontsize=12)
title!("Florida and the counties") 
xlabel!("longitude",guidefontsize=14)
ylabel!("latitude",guidefontsize=14)
scatter!([-86],[27],marker=:star8,markersize=10,legend=false)
display("image/png", pp)

# %%
#add annotation
shapeFileURL = file_SHP
tbl = Shapefile.Table(shapeFileURL)
shp = Shapefile.shapes(Shapefile.Table(shapeFileURL))
pp=pp = plot(shp,xrotation=45,xtickfontsize=12,
            ytickfontsize=12)
title!("Florida and the counties") 
xlabel!("longitude",guidefontsize=14)
ylabel!("latitude",guidefontsize=14)
display("image/png", pp)

# %%
#alter the position of the annotation
position_x = -86
position_y = 27
pp=scatter!(pp, [position_x+2],[position_y+2],marker=:star8,markersize=10,legend=false)
display("image/png", pp)

# %%
#make animation of the annotation movements
shapeFileURL = file_SHP
tbl = Shapefile.Table(shapeFileURL)
shp = Shapefile.shapes(Shapefile.Table(shapeFileURL))
pp = plot(shp,xrotation=45,xtickfontsize=12,
            ytickfontsize=12)
title!("Florida and the counties") 
xlabel!("longitude",guidefontsize=14)
ylabel!("latitude",guidefontsize=14)

anim = @animate for i ∈ 1:10
    global pp
    position_x = -86 - 2*rand()
    position_y = 27 - 2*rand()
    pp=scatter!(pp, [position_x],[position_y],marker=:star8,markersize=10,legend=false)
    #display("image/png", pp)
end
gif(anim, "./animations/sightings.gif", fps = 2)
# Out:
# [ Info: Saved animation to /home/tasty/Documents/repos/JuliaPlottingExploration/Plotting/animations/sightings.gif
# Plots.AnimatedGif("/home/tasty/Documents/repos/JuliaPlottingExploration/Plotting/animations/sightings.gif")

# %%
run(`ls`)
# Out:
# animations
# fileMapStuff
# plottingJL1a.ipynb
# plottingJL1b.ipynb
# plottingJL1c.ipynb
# plottingJL1dMaps.ipynb
# testAnimation2.gif
# testAnimation.gif
# testplot.pdf
# testplot.png
# tl_2017_12_cousub
# tmp.gif
# united_states_florida_administrative_boundaries_polygon
# Process(`ls`, ProcessExited(0))

# %%
#change the axis lims
shapeFileURL = file_SHP
tbl = Shapefile.Table(shapeFileURL)
shp = Shapefile.shapes(Shapefile.Table(shapeFileURL))
pp=pp = plot(shp,xrotation=45,xtickfontsize=12,
            ytickfontsize=12, xlims = [-90,-70], ylims = [22,33])
title!("Florida and the counties") 
xlabel!("longitude",guidefontsize=14)
ylabel!("latitude",guidefontsize=14)
display("image/png", pp)

# %%
#change the axis lims to focus on 'orlando'
xlims_orlando = []
ylims_orlando = []
shapeFileURL = file_SHP
tbl = Shapefile.Table(shapeFileURL)
shp = Shapefile.shapes(Shapefile.Table(shapeFileURL))
pp = plot(shp,xrotation=45,xtickfontsize=12,
            ytickfontsize=12)
title!("Florida and the counties") 
xlabel!("longitude",guidefontsize=14)
ylabel!("latitude",guidefontsize=14)
display("image/png", pp)

# %%
fieldnames(typeof(shp))
# Out:
# ()

# %%
tblDF = tbl |> DataFrame
# Out:
# 316×19 DataFrame
#  Row │ geometry              STATEFP  COUNTYFP  COUSUBFP  COUSUBNS  GEOID      ⋯
#      │ Polygon               String   String    String    String    String     ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │ Polygon(3175 Points)  12       083       90897     01935751  1208390897 ⋯
#    2 │ Polygon(1499 Points)  12       081       92290     01935861  1208192290
#    3 │ Polygon(252 Points)   12       081       92600     01935887  1208192600
#    4 │ Polygon(1335 Points)  12       031       91644     02583398  1203191644
#    5 │ Polygon(431 Points)   12       031       90110     02583392  1203190110 ⋯
#    6 │ Polygon(191 Points)   12       031       91640     02583396  1203191640
#    7 │ Polygon(2246 Points)  12       083       92483     01935878  1208392483
#    8 │ Polygon(1026 Points)  12       095       93198     01935935  1209593198
# ...

# %%
using DataFrames

# %%
names(tblDF)
# Out:
# 19-element Vector{String}:
#  "geometry"
#  "STATEFP"
#  "COUNTYFP"
#  "COUSUBFP"
#  "COUSUBNS"
#  "GEOID"
#  "NAME"
#  "NAMELSAD"
#  "LSAD"
#  "CLASSFP"
#  "MTFCC"
#  "CNECTAFP"
#  "NECTAFP"
#  "NCTADVFP"
#  "FUNCSTAT"
#  "ALAND"
#  "AWATER"
#  "INTPTLAT"
#  "INTPTLON"

# %%
tblDF[!,:NAME]
# Out:
# 316-element Vector{String}:
#  "East Marion"
#  "Myakka City"
#  "Palmetto"
#  "Jacksonville North"
#  "Baldwin"
#  "Jacksonville Beaches"
#  "Ocala"
#  "Southwest Orange"
#  "Apopka"
#  "East Orange"
#  "Winter Garden-Ocoee"
#  "Orlando"
#  "Everglades"
#  ⋮
#  "North Port"
#  "Cocoa Beach-Cape Canaveral"
#  "Winter Haven-Auburndale"
#  "Glades"
#  "Western Community"
#  "Malabar"
#  "Melbourne"
#  "Melbourne Shores-Floridana Beach"
#  "Merritt Island"
#  "Space Center"
#  "Callahan-Hilliard"
#  "Fernandina Beach"

# %%
tblDF[1,:]
# Out:
# DataFrameRow
#  Row │ geometry              STATEFP  COUNTYFP  COUSUBFP  COUSUBNS  GEOID      ⋯
#      │ Polygon               String   String    String    String    String     ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │ Polygon(3175 Points)  12       083       90897     01935751  1208390897 ⋯
#                                                               13 columns omitted

# %%
tblDF[1,1]
# Out:
# Polygon(3175 Points)

# %%
import Pkg
Pkg.add("Plots")
Pkg.add("Shapefile")
Pkg.add("RecipesBase")
# Out:
#     Updating registry at `~/.julia/registries/General.toml`
#    Resolving package versions...
#   No Changes to `~/.julia/environments/v1.8/Project.toml`
#   No Changes to `~/.julia/environments/v1.8/Manifest.toml`
#    Resolving package versions...
#   No Changes to `~/.julia/environments/v1.8/Project.toml`
#   No Changes to `~/.julia/environments/v1.8/Manifest.toml`
#    Resolving package versions...
#     Updating `~/.julia/environments/v1.8/Project.toml`
#   [3cdcf5f2] + RecipesBase v1.3.3
#   No Changes to `~/.julia/environments/v1.8/Manifest.toml`

# %%
using Plots
using Shapefile
using RecipesBase

# %%
@recipe function f(sf::Shapefile.Handle)
    # Extract coordinates and shapes
    xs = Float64[]
    ys = Float64[]
    shapes = Shapefile.shapes(sf)

    for shape in shapes
        append!(xs, [point.x for point in shape.points])
        append!(ys, [point.y for point in shape.points])
        append!(xs, NaN)
        append!(ys, NaN)
    end

    # Set plot attributes
    seriestype := :shape
    fillcolor := :yellow
    fillrange := 0
    linecolor := :black

    # Return coordinates
    xs, ys
end

# %%
# Load the shapefile
florida_shapefile_path = file_SHP
florida_sf = Shapefile.open(florida_shapefile_path)

# Plot the map
plot(florida_sf)
# Out:
# Cannot convert IOStream to series data for plotting
#
# Stacktrace:
#   [1] error(s::String)
#     @ Base ./error.jl:35
#   [2] _prepare_series_data(x::IOStream)
#     @ RecipesPipeline ~/.julia/packages/RecipesPipeline/XxUHt/src/series.jl:8
#   [3] _series_data_vector(x::IOStream, plotattributes::Dict{Symbol, Any})
#     @ RecipesPipeline ~/.julia/packages/RecipesPipeline/XxUHt/src/series.jl:36
#   [4] macro expansion
#     @ ~/.julia/packages/RecipesPipeline/XxUHt/src/series.jl:129 [inlined]
#   [5] apply_recipe(plotattributes::AbstractDict{Symbol, Any}, #unused#::Type{RecipesPipeline.SliceIt}, x::Any, y::Any, z::Any)
#     @ RecipesPipeline ~/.julia/packages/RecipesBase/z10lo/src/RecipesBase.jl:300
#   [6] _process_userrecipes!(plt::Any, plotattributes::Any, args::Any)
#     @ RecipesPipeline ~/.julia/packages/RecipesPipeline/XxUHt/src/user_recipe.jl:38
#   [7] recipe_pipeline!(plt::Any, plotattributes::Any, args::Any)
# ...
