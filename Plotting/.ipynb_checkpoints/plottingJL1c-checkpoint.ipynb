# %%
using RDatasets, StatsPlots, Interact, Blink

# %%
#import Pkg; Pkg.add("Blink")
# Out:
#    Resolving package versions...
#    Installed Hiccup ─── v0.2.2
#    Installed Lazy ───── v0.15.1
#    Installed Mustache ─ v1.0.15
#    Installed Mux ────── v1.0.1
#    Installed Blink ──── v0.12.6

# %%
iris = dataset("datasets", "iris");
println( iris[1:5,:] )
# Out:
# 5×5 DataFrame
#  Row │ SepalLength  SepalWidth  PetalLength  PetalWidth  Species
#      │ Float64      Float64     Float64      Float64     Cat…
# ─────┼───────────────────────────────────────────────────────────
#    1 │         5.1         3.5          1.4         0.2  setosa
#    2 │         4.9         3.0          1.4         0.2  setosa
#    3 │         4.7         3.2          1.3         0.2  setosa
#    4 │         4.6         3.1          1.5         0.2  setosa
#    5 │         5.0         3.6          1.4         0.2  setosa

# %%
typeof(iris)
# Out:
# DataFrame

# %%
iris_mat = Array(iris);
println( iris_mat[1:5,:] )
# Out:
# Any[5.1 3.5 1.4 0.2 CategoricalArrays.CategoricalValue{String, UInt8} "setosa"; 4.9 3.0 1.4 0.2 CategoricalArrays.CategoricalValue{String, UInt8} "setosa"; 4.7 3.2 1.3 0.2 CategoricalArrays.CategoricalValue{String, UInt8} "setosa"; 4.6 3.1 1.5 0.2 CategoricalArrays.CategoricalValue{String, UInt8} "setosa"; 5.0 3.6 1.4 0.2 CategoricalArrays.CategoricalValue{String, UInt8} "setosa"]

# %%
size(iris_mat)
# Out:
# (150, 5)

# %%
#plot first dimension of the 3 flower species in violin plots
violin(["F1" "F2" "F3"], [ iris_mat[1:50,1] iris_mat[51:100,1] iris_mat[101:150,1] ] , legend=false)

# %%
#plot first dimension of the 3 flower species in box plots
boxplot(["F1" "F2" "F3"], [ iris_mat[1:50,1] iris_mat[51:100,1] iris_mat[101:150,1] ] , legend=false)

# %%
#plot first dimension of the 3 flower species in violin plots with boxplot
violin(["F1" "F2" "F3"], [ iris_mat[1:50,1] iris_mat[51:100,1] iris_mat[101:150,1] ] , legend=false)
boxplot!(["F1" "F2" "F3"], [ iris_mat[1:50,1] iris_mat[51:100,1] iris_mat[101:150,1] ] , legend=false)

# %%
#data viewer
w = Window()
body!(w, dataviewer(iris))
# Out:
# ┌ Info: Listening on: 127.0.0.1:2340, thread id: 1
# └ @ HTTP.Servers /home/resort/.julia/packages/HTTP/z8l0i/src/Servers.jl:366
# names = map(collect ∘ keys, coltable) = Observable([:SepalLength, :SepalWidth, :PetalLength, :PetalWidth, :Species])
# Page(1, HTTP.WebSockets.WebSocket(UUID("976389c0-57b6-4e0b-a406-623382bf89ba"), 🔁   13s 127.0.0.1:2340:2340 RawFD(58), HTTP.Messages.Request:
# """
# GET /1?callback=1/1 HTTP/1.1
# Host: 127.0.0.1:2340
# Connection: Upgrade
# Pragma: no-cache
# Cache-Control: no-cache
# User-Agent: Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/102.0.5005.167 Electron/19.0.9 Safari/537.36
# Upgrade: websocket
# Origin: http://127.0.0.1:2340
# Sec-WebSocket-Version: 13
# Accept-Encoding: gzip, deflate, br
# Accept-Language: en-US
# Sec-WebSocket-Key: fNqbwwPCVCN3PiZNVlnJgw==
# Sec-WebSocket-Extensions: permessage-deflate; client_max_window_bits
#
# """, HTTP.Messages.Response:
# """
# HTTP/1.1 101 Switching Protocols
# Upgrade: websocket
# Connection: Upgrade
# Sec-WebSocket-Accept: PGDssqMHbeu9tAeB9lefwyckKj4=
#
# """, 9223372036854775807, 1024, false, UInt8[0x7b, 0x22, 0x74, 0x79, 0x70, 0x65, 0x22, 0x3a, 0x22, 0x63  …  0x72, 0x22, 0x3a, 0x66, 0x61, 0x6c, 0x73, 0x65, 0x7d, 0x7d], UInt8[], false, false), Dict{String, Any}("webio" => Blink.AtomShell.var"#19#20"{Blink.AtomShell.WebIOBlinkComm}(Blink.AtomShell.WebIOBlinkComm(Window(1, Electron(Process(`/home/resort/.julia/artifacts/aad3f721351c9550129f625fc52f51f4d0726586/electron /home/resort/.julia/packages/Blink/SMxOp/src/AtomShell/main.js port 7898`, ProcessRunning), Sockets.TCPSocket(RawFD(51) active, 0 bytes waiting), Dict{String, Any}("callback" => Blink.var"#1#2"())), Page(#= circular reference @-5 =#), Task (done) @0x00007fc1a11a6400))), "callback" => Blink.var"#1#2"()), Distributed.Future(1, 1, 1, ReentrantLock(nothing, 0x00000000, 0x00, Base.GenericCondition{Base.Threads.SpinLock}(Base.InvasiveLinkedList{Task}(nothing, nothing), Base.Threads.SpinLock(0)), (2, 140472177474784, 140472177451920)), Some(true)))

# %%
@df iris marginalhist(:PetalLength, :PetalWidth)

# %%
@df iris corrplot(cols(1:4), grid = false)

# %%
iris_mat = Matrix{Float64}(iris_mat[:,1:4])
# Out:
# 150×4 Matrix{Float64}:
#  5.1  3.5  1.4  0.2
#  4.9  3.0  1.4  0.2
#  4.7  3.2  1.3  0.2
#  4.6  3.1  1.5  0.2
#  5.0  3.6  1.4  0.2
#  5.4  3.9  1.7  0.4
#  4.6  3.4  1.4  0.3
#  5.0  3.4  1.5  0.2
#  4.4  2.9  1.4  0.2
#  4.9  3.1  1.5  0.1
#  5.4  3.7  1.5  0.2
#  4.8  3.4  1.6  0.2
#  4.8  3.0  1.4  0.1
#  ⋮
#  6.0  3.0  4.8  1.8
#  6.9  3.1  5.4  2.1
#  6.7  3.1  5.6  2.4
#  6.9  3.1  5.1  2.3
#  5.8  2.7  5.1  1.9
#  6.8  3.2  5.9  2.3
#  6.7  3.3  5.7  2.5
#  6.7  3.0  5.2  2.3
#  6.3  2.5  5.0  1.9
#  6.5  3.0  5.2  2.0
#  6.2  3.4  5.4  2.3
#  5.9  3.0  5.1  1.8

# %%
corrplot( iris_mat )

# %%
cornerplot( iris_mat )

# %%
# Equal Area histograms, so that each box has the same number of sample points (same area)
pnts = randn(10^4)
ea_histogram( pnts )

# %%
#quantile-quantile plots (qq pltos)
pnts = randn( 10^2 )
qqnorm( pnts , qqline = :R , size = (300,300) )

# %%
pnts = randn( 10^2 )
qqnorm( 1:100 , pnts , qqline = :R , size = (300,300) )

# %%
groupedbar( iris_mat[:,[1,3]] , bar_position = :stack , bar_width=0.7 )

# %%
groupedbar(rand(10,3), bar_position = :dodge, bar_width=0.7)

# %%
histogram2d(randn(1000),randn(1000))

# %%
histogram2d( iris_mat[:,1] , iris_mat[:,3] )

# %%
histogram2d( iris_mat[1:50,1] , iris_mat[51:100,1] )

# %%
#annotate
histogram2d( iris_mat[1:50,1] , iris_mat[51:100,1] )
annotate!([ (5.2,5.7,"dense") ])

# %%
using Dates

# %%
x = Date(2023,1,1):Day(1):Date(2023,1,10)
y = rand(10)

plot( x , y , xaxis=(xtickrotation = 45) )
